# %% [markdown]
# # Visualize Flight
# Notebook auto-created from `visualize_flight.py`.

# %%
# Auto-generated notebook for: visualize_flight.py
# Run the cells below to execute the flight visualisation.

# Uncomment the next line to run the whole script at once:
# %run '/mnt/c/Users/hilary/Downloads/visualize_flight.py'

# ── Or paste / import individual sections here ──────────────────
from dronekit import connect, VehicleMode
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time

print('Notebook ready.  Edit cells below to start.')
